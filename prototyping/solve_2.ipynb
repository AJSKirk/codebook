# %%
import decode
with open('data/stage_2_caesar.txt') as f:
    ciphertext = decode.CaesarCiphertext(f.read().strip().upper())

print(ciphertext)
# Out:
# MHILY LZA ZBHL XBPZXBL MVYABUHL HWWPBZ JSHBKPBZ
# JHLJBZ KPJABT HYJHUBT LZA ULBAYVU

# %%
ciphertext.brute()
# Out:
# 0   -   MHILY LZA ZBHL XBPZXBL MVYABUHL HWWPBZ JSHBKPBZXJHLJBZ KPJABT HYJHUBT LZA ULBAYVU
# 1   -   NIJMZ MAB ACIM YCQAYCM NWZBCVIM IXXQCA KTICLQCAYKIMKCA LQKBCU IZKIVCU MAB VMCBZWV
# 2   -   OJKNA NBC BDJN ZDRBZDN OXACDWJN JYYRDB LUJDMRDBZLJNLDB MRLCDV JALJWDV NBC WNDCAXW
# 3   -   PKLOB OCD CEKO AESCAEO PYBDEXKO KZZSEC MVKENSECAMKOMEC NSMDEW KBMKXEW OCD XOEDBYX
# 4   -   QLMPC PDE DFLP BFTDBFP QZCEFYLP LAATFD NWLFOTFDBNLPNFD OTNEFX LCNLYFX PDE YPFECZY
# 5   -   RMNQD QEF EGMQ CGUECGQ RADFGZMQ MBBUGE OXMGPUGECOMQOGE PUOFGY MDOMZGY QEF ZQGFDAZ
# 6   -   SNORE RFG FHNR DHVFDHR SBEGHANR NCCVHF PYNHQVHFDPNRPHF QVPGHZ NEPNAHZ RFG ARHGEBA
# 7   -   TOPSF SGH GIOS EIWGEIS TCFHIBOS ODDWIG QZOIRWIGEQOSQIG RWQHIA OFQOBIA SGH BSIHFCB
# 8   -   UPQTG THI HJPT FJXHFJT UDGIJCPT PEEXJH RAPJSXJHFRPTRJH SXRIJB PGRPCJB THI CTJIGDC
# 9   -   VQRUH UIJ IKQU GKYIGKU VEHJKDQU QFFYKI SBQKTYKIGSQUSKI TYSJKC QHSQDKC UIJ DUKJHED
# ...

# %%
# FABER EST SUAE QUISQUE FORTUNAE APPIUS CLAUDIUSQCAECUS DICTUM ARCANUM EST NEUTRON
